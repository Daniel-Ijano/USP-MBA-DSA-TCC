# %%
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account

# %% [markdown]
# #### Ler tabela do Google Big Query

# %%
# Create the connection with Google Cloud
def create_connection():
        # Set the credentials and create the connection
        key_path = "../usp-mba-dsa-tcc-4277103d9155.json"

        credentials = service_account.Credentials.from_service_account_file(
            key_path,
            scopes=["https://www.googleapis.com/auth/bigquery"]
        )

        client = bigquery.Client(
            credentials=credentials,
            project=credentials.project_id,
        )
        return client

client = create_connection()

# %%
# Perform a query.
QUERY = ("""
    SELECT DISTINCT Categoria, Marca, Especie, Grupo, Embalagem, Loja, Descricao, offer_id
    FROM `usp-mba-dsa-tcc.ecommerce_offers.vw_dim_offers`
""")
query_job = client.query(QUERY)  # API request
rows = query_job.result()  # Waits for query to finish

offers = rows.to_dataframe()

# %%
offers.head(2)
# Out:
#      Categoria          Marca   Especie      Grupo Embalagem    Loja  \
# 0  Racao Umida            N&D  Cachorro       None      140g  Cobasi
# 1   Racao Seca  Nestlé Purina      Gato  Castrados      700g    Petz
#
#                                            Descricao  \
# 0  Ração Úmida N&amp;D Quinoa Cães Weight Managem...
# 1   Ração Cat Chow para Gatos Castrados Sabor Frango
#
#                                             offer_id
# 0  b'Q\x8c\xc4\xef\x08m\x8a\xde\xaf\x92\xc4\xdc)P...
# 1  b"'\x15\xbb\xcf\x1e\xda\x04\x8a\x02\xa0\xdc\xf...

# %%
# Creating a copy of the dataframe and editing
golden_1kg_adultos=offers.query("Categoria == 'Racao Seca' and Marca == 'Golden' and Especie == 'Cachorro' and Grupo == 'Adultos' and Embalagem == '1Kg'")
golden_1kg_adultos.head(2)
# Out:
#       Categoria   Marca   Especie    Grupo Embalagem     Loja  \
# 388  Racao Seca  Golden  Cachorro  Adultos       1Kg   Cobasi
# 396  Racao Seca  Golden  Cachorro  Adultos       1Kg  Petlove
#
#                                              Descricao  \
# 388  Ração Golden Fórmula Light Cães Adultos Porte ...
# 396  Ração Seca PremieR Pet Golden Formula Mini Bit...
#
#                                               offer_id
# 388  b'<\xb1\x95\x98\x18\xfer\x05#J\x0e\xacIW\xb9\x...
# 396  b'\x17G1\xc9d(RQ!\xfc\xe80\x91\xc5\xc0-\xfa2\x...

# %% [markdown]
# #### Import Language Model

# %%
# https://spacy.io/models/pt#pt_core_news_lg
import spacy
nlp = spacy.load("pt_core_news_lg")

# %% [markdown]
# ##### Testes

# %%
w1 = "banana"
w2 = "mamão"

# Transform into spacy object
w1 = nlp.vocab[w1]
w2 = nlp.vocab[w2]

w1.similarity(w2)

# %%
#Hx/o//XEL8KnXyhZfnMRDK55G+AoABfz3kKwGJLKAx8=
offer1 = nlp("Ração Naturalis Lifebites Cães Filhotes Porte Pequeno Peru, Frango, Legumes e Frutas 1kg")

#UTZQ/dqXqO94qscRScp/6ehZY6hZmnWKmeSatqM7QVw=
offer2 = nlp("Ração Seca Total Naturalis Peru, Frango e Frutas para Cães Adultos Porte Pequeno - 1 Kg")

offer1.similarity(offer2)

# %%
#N954En5srMC24fi4K/3au+jmzCuc6guQx7x1IYwDvM0=
offer2 = nlp("Ração Naturalis Lifebites Cães Sênior Porte Pequeno Peru, Frango, Legumes e Frutas 1kg")
offer1.similarity(offer2)

# %%
#fTRC8JQlzMAhL3qgENIRP0HJz2x+QbmoWUqfvyX1cfs=
offer2 = nlp("Ração Úmida Fórmula Natural Vet Care Recuperação para Cães e Gatos 270 g")
offer1.similarity(offer2)

# %%
#qB1kHKxZOmz4J6A/OfWybRC260BtjXb0vm/9q4SlM1I=
offer2 = nlp("Ração Naturalis Lifebites Cães Adultos Porte Médio e Grande Peru, Frango, Legumes e Frutas 2,5kg")
offer1.similarity(offer2)

# %%
#yfkeevB9AQTAnuC97yDgi7DWo8H/anZQ57/QHngrKLY=
offer2 = nlp("Ração Naturalis Lifebites Gatos Adultos Peru, Frango e Frutas 1,5kg")
offer1.similarity(offer2)

# %%
#KlqW6FrilTY99taOFOyzXbwjXgR/2SkyRzNaYUlFIHA=
offer2 = nlp("Ração Naturalis Cães Filhotes Pequeno Porte Peru, Frango e Frutas 1 kg")
offer1.similarity(offer2)

# %% [markdown]
# ##### Para Valer

# %%
from unidecode import unidecode

offer1 = nlp(unidecode(offers["Descricao"][0]))
offer2 = nlp(unidecode(offers["Descricao"][2]))

print(f"{offer1}\n{offer2}\n{offer1.similarity(offer2)}")

# %%
#offers.loc[[0]]
print(offers["URL"][0])
print(offers["URL"][2])

# %%
import pandas as pd
import spacy
nlp = spacy.load("pt_core_news_lg")
data = {"palavra": ["gato", "cachorro", "peixe", "ave"]}
df = pd.DataFrame(data)

def calcular_similaridade(palavra1, palavra2):
    doc1 = nlp(palavra1)
    doc2 = nlp(palavra2)
    return doc1.similarity(doc2)

num_palavras = len(df)
similaridade_matrix = []

for i in range(num_palavras):
    linha = []
    for j in range(num_palavras):
        palavra1 = df.iloc[i]["palavra"]
        palavra2 = df.iloc[j]["palavra"]
        similaridade = calcular_similaridade(palavra1, palavra2)
        linha.append(similaridade)
    similaridade_matrix.append(linha)

# Crie um novo DataFrame com a matriz de similaridade
df_similaridade = pd.DataFrame(similaridade_matrix, columns=df["palavra"], index=df["palavra"])

# %%
df_similaridade
# Out:
# palavra       gato  cachorro     peixe       ave
# palavra
# gato      1.000000  0.836820  0.415578  0.395356
# cachorro  0.836820  1.000000  0.442158  0.357636
# peixe     0.415578  0.442158  1.000000  0.452842
# ave       0.395356  0.357636  0.452842  1.000000

# %%
import pandas as pd
import spacy
nlp = spacy.load("pt_core_news_lg")
df = golden_1kg_adultos

def calcular_similaridade(offer1, offer2):
    doc1 = nlp(offer1)
    doc2 = nlp(offer2)
    return doc1.similarity(doc2)

num_offers = len(df)
similaridade_matrix = []

for i in range(num_offers):
    linha = []
    for j in range(num_offers):
        offer1 = df.iloc[i]["Descricao"]
        offer2 = df.iloc[j]["Descricao"]
        similaridade = calcular_similaridade(offer1, offer2)
        linha.append(similaridade)
    similaridade_matrix.append(linha)

# Crie um novo DataFrame com a matriz de similaridade
df_similaridade = pd.DataFrame(similaridade_matrix, columns=df["Descricao"], index=df["Descricao"])
df_similaridade
# Out:
# Descricao                                           Ração Golden Fórmula Light Cães Adultos Porte Pequeno Frango e Arroz 1 kg  \
# Descricao
# Ração Golden Fórmula Light Cães Adultos Porte P...                                           1.000000
# Ração Seca PremieR Pet Golden Formula Mini Bits...                                           0.851585
# Ração Golden Formula Cães Adultos Raças Pequena...                                           0.952302
# Ração Seca PremieR Pet Golden Seleção Natural p...                                           0.831610
# Ração Seca PremieR Pet Golden Formula Carne e A...                                           0.845246
# Ração Golden Fórmula Cães Adultos Raças Pequena...                                           0.958886
# Ração Premier Golden Formula Cães Adultos Light...                                           0.895269
# Ração Premier Golden Formula Cães Adultos Frang...                                           0.896673
# Ração Golden Seleção Natural Cães Adultos Porte...                                           0.969685
# Ração Seca PremieR Pet Golden Formula Peru & Ar...                                           0.814956
# Ração Golden Fórmula Cães Adultos Raças Pequena...                                           0.964037
# Ração Golden Fórmula Cães Adultos Raças Pequena...                                           0.952863
#
# Descricao                                           Ração Seca PremieR Pet Golden Formula Mini Bits Salmão e Arroz para Cães Adultos de Raças Pequenas - 1 Kg  \
# Descricao
# Ração Golden Fórmula Light Cães Adultos Porte P...                                           0.851585
# Ração Seca PremieR Pet Golden Formula Mini Bits...                                           1.000000
# Ração Golden Formula Cães Adultos Raças Pequena...                                           0.887840
# Ração Seca PremieR Pet Golden Seleção Natural p...                                           0.928221
# Ração Seca PremieR Pet Golden Formula Carne e A...                                           0.985262
# Ração Golden Fórmula Cães Adultos Raças Pequena...                                           0.849994
# Ração Premier Golden Formula Cães Adultos Light...                                           0.916645
# Ração Premier Golden Formula Cães Adultos Frang...                                           0.923491
# Ração Golden Seleção Natural Cães Adultos Porte...                                           0.876024
# Ração Seca PremieR Pet Golden Formula Peru & Ar...                                           0.925947
# Ração Golden Fórmula Cães Adultos Raças Pequena...                                           0.883262
# Ração Golden Fórmula Cães Adultos Raças Pequena...                                           0.831636
#
# Descricao                                           Ração Golden Formula Cães Adultos Raças Pequenas Carne e Arroz Mini Bits 1 kg  \
# Descricao
# Ração Golden Fórmula Light Cães Adultos Porte P...                                           0.952302
# Ração Seca PremieR Pet Golden Formula Mini Bits...                                           0.887840
# Ração Golden Formula Cães Adultos Raças Pequena...                                           1.000000
# Ração Seca PremieR Pet Golden Seleção Natural p...                                           0.851025
# Ração Seca PremieR Pet Golden Formula Carne e A...                                           0.872104
# Ração Golden Fórmula Cães Adultos Raças Pequena...                                           0.973250
# Ração Premier Golden Formula Cães Adultos Light...                                           0.907901
# Ração Premier Golden Formula Cães Adultos Frang...                                           0.917376
